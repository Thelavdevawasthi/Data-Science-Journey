# %%
import pandas as pd
pd.Series([4,7,9])
# Out:
# 0    4
# 1    7
# 2    9
# dtype: int64

# %%
#Custom index
import pandas as pd
pd.Series([44,79,69])
s = pd.Series([44,79,69], index= ["Ram", "Kishor", "Sita"])
print(s)
# Out:
# Ram       44
# Kishor    79
# Sita      69
# dtype: int64

# %%
s["Sita"]
# Out:
# np.int64(69)

# %% [markdown]
# # Data Series

# %%
data = {
    "name": ["Ram", "Hari", "Shyam"],
    "age": [25, 30, 35],
    "city": ["Kathmandu", "Pokhara", "Biratnagar"]
}
frame = pd.DataFrame(data)
print(frame)
frame.index
# Out:
#     name  age        city
# 0    Ram   25   Kathmandu
# 1   Hari   30     Pokhara
# 2  Shyam   35  Biratnagar
# RangeIndex(start=0, stop=3, step=1)
