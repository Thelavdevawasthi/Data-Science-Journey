# %%
#Assigning Different data
a = 5
b = "World"
c = True
d = 5.5 
#Checking Data Types
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'bool'>
# <class 'float'>

# %% [markdown]
# #Type Casting
# a = "5999"
# b = "1566"
# print(a+b)    #String Concatenate
#
# print(int(a) + int(b))   #Type Converted to INT

# %% [markdown]
# #String Methods & Manipulation

# %%
#String Method
name = "mississipi"
name.upper()
name.endswith("i") #check the ending variable
name.count("s")    #Count no. of occurance
# Out:
# 4

# %% [markdown]
# #String Methods

# %%
l = "Computerkite"
print(len(l))    #Check legth
# Out:
# 12

# %%
#Replace 
x =  "Hello Everyone"
x.replace("Everyone", "Friends")
# Out:
# 'Hello Friends'

# %%
l[0:4]  #indexing 
l[7:-1]    #neg_indexing
# Out:
# 'rkit'
